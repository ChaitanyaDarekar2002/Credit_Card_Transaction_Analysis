# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('cc_add.csv')
data
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      31-12-2023  Week-53  Q4          2023
# 1                   96      31-12-2023  Week-53  Q4          2023
# ...

# %%
df=pd.read_csv('cust_add.csv')
df
# Out:
#      Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0     963607849            42      F                3      Uneducated
# 1     932954954            62      F                0     High School
# 2     961650885            47      F                3       Doctorate
# 3     917695309            49      M                5        Graduate
# 4     957309271            53      F                3        Graduate
# ..          ...           ...    ...              ...             ...
# 180   964474458            38      M                1     High School
# 181   962482385            44      F                1        Graduate
# 182   919695363            52      F                1        Graduate
# 183   931822111            36      M                2         Unknown
# 184   925168075            58      F                2        Graduate
#
#     Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
data.value_counts().sum()
# Out:
# np.int64(185)

# %%
data.isnull().sum()
# Out:
# Client_Num               0
# Card_Category            0
# Annual_Fees              0
# Activation_30_Days       0
# Customer_Acq_Cost        0
# Week_Start_Date          0
# Week_Num                 0
# Qtr                      0
# current_year             0
# Credit_Limit             0
# Total_Revolving_Bal      0
# Total_Trans_Amt          0
# Total_Trans_Ct           0
# Avg_Utilization_Ratio    0
# Use Chip                 0
# Exp Type                 0
# Interest_Earned          0
# Delinquent_Acc           0
# dtype: int64

# %%
data.describe()
# Out:
#          Client_Num  Annual_Fees  Activation_30_Days  Customer_Acq_Cost  \
# count  1.850000e+02   185.000000          185.000000         185.000000
# mean   9.386542e+08   278.351351            0.567568          98.508108
# std    1.702981e+07   126.544204            0.496758          26.994991
# min    9.110172e+08    95.000000            0.000000          41.000000
# 25%    9.247779e+08   150.000000            0.000000          80.000000
# 50%    9.401193e+08   275.000000            1.000000          99.000000
# 75%    9.530579e+08   395.000000            1.000000         114.000000
# max    9.689362e+08   495.000000            1.000000         172.000000
#
#        current_year  Credit_Limit  Total_Revolving_Bal  Total_Trans_Amt  \
# count         185.0    185.000000           185.000000       185.000000
# mean         2023.0   9012.424324          1228.335135      5464.908108
# std             0.0   9336.599854           776.770241      6960.851700
# ...

# %%
df.isnull().sum()
# Out:
# Client_Num                 0
# Customer_Age               0
# Gender                     0
# Dependent_Count            0
# Education_Level            0
# Marital_Status             0
# state_cd                   0
# Zipcode                    0
# Car_Owner                  0
# House_Owner                0
# Personal_loan              0
# contact                    0
# Customer_Job               0
# Income                     0
# Cust_Satisfaction_Score    0
# dtype: int64

# %%
df.describe()
# Out:
#          Client_Num  Customer_Age  Dependent_Count       Zipcode  \
# count  1.850000e+02    185.000000       185.000000    185.000000
# mean   9.386542e+08     46.016216         2.427027  91539.864865
# std    1.702981e+07      8.596938         1.353869   2848.184797
# min    9.110172e+08     27.000000         0.000000  53010.000000
# 25%    9.247779e+08     40.000000         1.000000  91750.000000
# 50%    9.401193e+08     45.000000         2.000000  91750.000000
# 75%    9.530579e+08     53.000000         3.000000  91750.000000
# max    9.689362e+08     65.000000         5.000000  91750.000000
#
#               Income  Cust_Satisfaction_Score
# count     185.000000               185.000000
# mean    63164.021622                 3.491892
# std     60786.315450                 1.441312
# min      2565.000000                 1.000000
# 25%     22287.000000                 2.000000
# 50%     45468.000000                 4.000000
# 75%     84114.000000                 5.000000
# ...

# %%
data.columns
# Out:
# Index(['Client_Num', 'Card_Category', 'Annual_Fees', 'Activation_30_Days',
#        'Customer_Acq_Cost', 'Week_Start_Date', 'Week_Num', 'Qtr',
#        'current_year', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Total_Trans_Amt', 'Total_Trans_Ct', 'Avg_Utilization_Ratio',
#        'Use Chip', 'Exp Type', 'Interest_Earned', 'Delinquent_Acc'],
#       dtype='str')

# %%
Customer_Acq_Cost_Value=data.groupby('Card_Category')['Customer_Acq_Cost'].sum()

# %%
Customer_Acq_Cost_Value.plot(kind='bar')
# Out:
# <Axes: xlabel='Card_Category'>

# %%
RevenueByType=data.groupby('Exp Type')['Total_Trans_Amt'].sum()

# %%
RevenueByType.plot(kind='barh',color='orange')
# Out:
# <Axes: ylabel='Exp Type'>

# %%
IncomeBYEduction=df.groupby('Education_Level')['Income'].sum()

# %%
IncomeBYEduction.plot(kind='line')
# Out:
# <Axes: xlabel='Education_Level'>

# %%
INcomeByGender=df.groupby('Gender')['Income'].sum()

# %%
INcomeByGender.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
NUM=data.select_dtypes(include='number')

# %%
sns.heatmap(NUM.corr(),cmap='cool')
# Out:
# <Axes: >

# %%
DFNUM=df.select_dtypes(include='number')

# %%
sns.heatmap(DFNUM.corr(),cmap='coolwarm')
# Out:
# <Axes: >
